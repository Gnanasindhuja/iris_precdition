# %%
import pandas as pd

# %%
college=pd.read_csv("C:/Users/STUDENT/Downloads/labels_my-project-name_2023-08-03-11-55-50.csv")

# %%
college.head()
# Out:
# Empty DataFrame
# Columns: [label_name, bbox_x, bbox_y, bbox_width, bbox_height, image_name, image_width, image_height]
# Index: []

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    0 non-null      object
#  1   bbox_x        0 non-null      object
#  2   bbox_y        0 non-null      object
#  3   bbox_width    0 non-null      object
#  4   bbox_height   0 non-null      object
#  5   image_name    0 non-null      object
#  6   image_width   0 non-null      object
#  7   image_height  0 non-null      object
# dtypes: object(8)
# memory usage: 0.0+ bytes

# %%
college.sum()
# Out:
# label_name      0.0
# bbox_x          0.0
# bbox_y          0.0
# bbox_width      0.0
# bbox_height     0.0
# image_name      0.0
# image_width     0.0
# image_height    0.0
# dtype: float64

# %%
college.isnull().sum()
# Out:
# label_name      0.0
# bbox_x          0.0
# bbox_y          0.0
# bbox_width      0.0
# bbox_height     0.0
# image_name      0.0
# image_width     0.0
# image_height    0.0
# dtype: float64

# %%
college.dropna
# Out:
# <bound method DataFrame.dropna of Empty DataFrame
# Columns: [label_name, bbox_x, bbox_y, bbox_width, bbox_height, image_name, image_width, image_height]
# Index: []>

# %%
college.describe()
# Out:
#        label_name bbox_x bbox_y bbox_width bbox_height image_name image_width  \
# count           0      0      0          0           0          0           0
# unique          0      0      0          0           0          0           0
# top           NaN    NaN    NaN        NaN         NaN        NaN         NaN
# freq          NaN    NaN    NaN        NaN         NaN        NaN         NaN
#
#        image_height
# count             0
# unique            0
# top             NaN
# freq            NaN

# %%
import seaborn as sns

# %%
sns.pairplot(college)

# %%
k=sns.boxplot(data=college)

# %%
sns.jointplot(data=college)

# %%
sns.displot(data=college)

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
testing=img.imread("C:/Users/STUDENT/Desktop/shopping.png")
plt.imshow(testing)

# %%
start_point=(4,4)
End_point=(220,220)
color=(255,0,0)
thickness=9
import cv2

# %%
testing=cv2.rectangle(testing,start_point,End_point,color,thickness)
testing
# Out:
# array([[[6.1176473e-01, 3.4117648e-01, 1.8039216e-01],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00]],
#
#        [[2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00]],
#
#        [[2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         [2.5500000e+02, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
# ...

# %%
cv2.imshow("name",testing)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8412/3638387457.py in <module>
# ----> 1 cv2.imshow("name",testing)
#       2 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined
